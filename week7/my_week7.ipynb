# %%
import os
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(os.path.join('data', 'Wine_Quality_Data.csv'))

# %%
data.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
data.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %%
quality_categories = (data.quality).astype('category')
color_categories =  (data.color == 'red').astype('int').astype('category')
y = pd.concat([quality_categories, color_categories], axis=1)
y[:3]
# Out:
#   quality color
# 0       5     1
# 1       5     1
# 2       5     1

# %%
X_columns = [col for col in data.columns if not col in ['quality', 'color']]
X = data[X_columns]
X[:3]
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.pairplot(data, hue='color')
